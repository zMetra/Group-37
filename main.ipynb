# %%
import pandas as pd

# %%
df = pd.read_csv("ballfields.csv")
print(df.head())
# Out:
#          field_name          x          y  objectid  area  perimeter  \
# 0      McBride Park -79.907773  40.368990         1   0.0        0.0
# 1    Carmalt School -80.006456  40.386580         2   0.0        0.0
# 2       Sam Bryan 2 -80.006881  40.389443         3   0.0        0.0
# 3       Sam Bryan 1 -80.007051  40.389711         4   0.0        0.0
# 4  Brookline T-Ball -80.007183  40.390456         5   0.0        0.0
#
#    ballfields  ballfiel_1  id  polygonid  scale  angle       point_x  \
# 0         1.0         1.0  72        0.0    0.0    0.0  1.367323e+06
# 1         2.0         2.0  27        0.0    0.0    0.0  1.339998e+06
# 2         3.0         3.0  24        0.0    0.0    0.0  1.339906e+06
# 3         4.0         4.0  23        0.0    0.0    0.0  1.339862e+06
# 4         5.0         5.0  22        0.0    0.0    0.0  1.339832e+06
#
#          point_y                                 dpw_name cityid active
# ...

# %%
df = pd.read_csv("parkfeatures.csv")
print(df.head())
# Out:
#    objectid  unicode                          name       facility_type  \
# 0      1664      NaN  Four Seasons Activity Center            Building
# 1      1665      NaN                    Picnic Hut            Building
# 2      1666      NaN             Basketball Courts  Court - Basketball
# 3      1667      NaN                 Tennis Courts      Court - Tennis
# 4      1668      NaN          Off Leash Dog Park 2            Dog Park
#
#    type_code      center center_code                  feature_name  \
# 0       10.0  Boyce Park          BP  Four Seasons Activity Center
# 1       10.0  Boyce Park          BP                    Picnic Hut
# 2       31.0  Boyce Park          BP             Basketball Courts
# 3       32.0  Boyce Park          BP                 Tennis Courts
# 4       61.0  Boyce Park          BP          Off Leash Dog Park 2
#
#                                              website  capacity  ...  \
# ...

# %%
df = pd.read_csv("trails.csv")
print(df.head())
# Out:
#    objectid trail_id trail_name park_name_short       park_name  \
# 0     12352   RH2182                         RH      Round Hill
# 1     12359   RH6197                         RH      Round Hill
# 2     12390  HH15413                         HH  Harrison Hills
# 3     12426  HH16723        NaN              HH  Harrison Hills
# 4     12427  HH16274        NaN              HH  Harrison Hills
#
#         park_name_full blaze_color_full blaze_color_short base_color  \
# 0      Round Hill Park              NaN               NaN        NaN
# 1      Round Hill Park              NaN               NaN        NaN
# 2  Harrison Hills Park           <Null>            <Null>        NaN
# 3  Harrison Hills Park              NaN               NaN        NaN
# 4  Harrison Hills Park              NaN               NaN        NaN
#
#   cap_color  ...   mileage track track_num     difficulty   configuration  \
# 0       NaN  ...  0.135136   NaN       NaN            NaN             NaN
# ...

# %%
df = pd.read_csv("waterfeatures.csv")
print(df.head())
# Out:
#            id                                  name control_type  \
# 0  1816791851                        Able Long Park   Continuous
# 1  1599892422               Albert Turk Graham Park       On/Off
# 2  1422043278             Allegheny Commons Arch St   Continuous
# 3  1237191582  Allegheny Commons East Tennis Courts   Continuous
# 4  1146184773                Allegheny Commons Pool   Continuous
#
#         feature_type inactive              make  \
# 0  Drinking Fountain        f  Regular Fountain
# 1  Drinking Fountain        f   Most Dependable
# 2  Drinking Fountain        f  Regular Fountain
# 3  Drinking Fountain        f  Regular Fountain
# 4  Drinking Fountain        f  Regular Fountain
#
#                                                image      neighborhood  \
# 0  https://tools.wprdc.org/images/pittsburgh/wate...         Beechview
# 1  https://tools.wprdc.org/images/pittsburgh/wate...  Crawford-Roberts
# ...

# %%
import matplotlib.pyplot as plt
import geopandas as gpd

# %%
neighbors = gpd.read_file('Neighborhoods_Files/Neighborhoods_.shp')
fig, ax = plt.subplots(figsize = (10,10))
neighbors.plot(ax=ax, linestyle='dashed')
plt.show()
